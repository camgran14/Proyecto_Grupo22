# %% [markdown]
# <div >
# <img src = "figs/dsa_banner.png" />
# </div>

# %% [markdown]
# # Primera entrega
#
# ### Integrantes:
#     - Catalina García García
#     - Camilo Alejandro Grande Sánchez
#     - Jesús Alberto Parada Pérez
#     - Jorge Esteban Caballero Rodríguez

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg
from sklearn.impute import SimpleImputer
from pca import pca
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\jorge\AppData\Roaming\Python\Python38\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %% [markdown]
# **Descripción  de la información:**
#
# La fundación "Future Education" (se modifica el nombre real por confidencialidad) tiene como objetivo incentivar practicas de innovación en la educación colombiana.
#
# Uno de los instrumentos que implementa en sus proyectos es una encuesta que busca medir las competencias que tienen maestros/docentes/agentes educativos y que son fundamentales para mejorar la calidad de la educación.
#
# Las *Competencias del Siglo XXI* es una adaptación del capitulo latinoamericano del proyecto ATC21s por sus siglas en ingles *"Assessment and Teaching of 21 st Century Skills"* de la Fundación Omar Dengo. Este instrumento consta de 20 preguntas asociadas a 5 competencias:
#
# 1. Creatividad e innovación
# 1. Pensamiento crítico
# 1. Resolución de problemas.
# 1. Comunicación.
# 1. Trabajo colaborativo.
#
# Se carga la base de datos que tiene 5270 observaciones y 33 variables, y la codificación de las 20 preguntas. Dentro de las 20 preguntas se encuentran 9 preguntas invertidas (es decir, preguntas que "más es menos", dónde la respuesta más alta es el peor valor)

# %% [markdown]
# ## Carga de datos
#
# Se cargan los datos de las fuentes dadas:

# %%
def cargar_datos(filename, nombre_base):
    print("--------------------------------------------------------")
    print(nombre_base)
    data = pd.read_excel(f"data/{filename}")
    display(data)
    return data


data = cargar_datos("Base perfilación de competencias_310823.xlsx", "Base de datos:")    
df_preguntas = cargar_datos("Base codificacion preguntas.xlsx", "Base de preguntas:")    


## Lista de las columnas en la base de datos
print("--------------------------------------------------------")
print(f"Lista de variables en la base de datos:")
display(data.columns)

## Registros y variables en la base de datos
print("--------------------------------------------------------")
print(
    f"La base de datos tiene {data.shape[0]} observaciones y {data.shape[1]} variables.\n"
)
# Out:
# --------------------------------------------------------
# Base de datos:
#         ID  Year  Mes                      solucion regional     departamento  \
# 0        1  2022    3              LABORATORIO VIVO   Centro     CUNDINAMARCA
# 1        1  2022    6              LABORATORIO VIVO   Centro     CUNDINAMARCA
# 2        2  2022    8                       ESTUDIA   Centro  VALLE DEL CAUCA
# 3        3  2022    3                       ESTUDIA   Centro     CUNDINAMARCA
# 4        4  2022    4  Modelos Educativos Flexibles   Caribe        ATLÁNTICO
# ...    ...   ...  ...                           ...      ...              ...
# 5265  3875  2022    4              LABORATORIO VIVO   Centro      BOGOTÁ D.C.
# 5266  3876  2022    3              LABORATORIO VIVO   Centro       EXTRANJERO
# 5267  3877  2022    4              LABORATORIO VIVO   Centro      BOGOTÁ D.C.
# 5268  3878  2022   11                       ESTUDIA   Centro     CUNDINAMARCA
# 5269  3878  2022    5                       ESTUDIA   Centro     CUNDINAMARCA
#
#      ubicacioninstitucion    cargo              edades    formacion  ...  \
# 0                   rural  Docente  Entre 26 y 35 años  Profesional  ...
# 1                   rural  Docente  Entre 26 y 35 años  Profesional  ...
# 2                  urbana  Docente    Mayor de 55 años     Posgrado  ...
# 3                  urbana  Docente  Entre 36 y 45 años     Posgrado  ...
# 4                  urbana  Docente  Entre 36 y 45 años     Posgrado  ...
# ...                   ...      ...                 ...          ...  ...
# 5265               urbana  Docente    Mayor de 55 años  Profesional  ...
# 5266               urbana  Docente  Entre 18 y 25 años  Profesional  ...
# 5267               urbana  Docente  Entre 18 y 25 años  Profesional  ...
# 5268               urbana  Docente  Entre 26 y 35 años     Posgrado  ...
# 5269               urbana  Docente  Entre 26 y 35 años     Posgrado  ...
#
#                  p11             p12             p13             p14  \
# 0     Constantemente  Constantemente  Constantemente  Constantemente
# 1     Constantemente         Siempre  Constantemente  Constantemente
# 2     Constantemente         Siempre         Siempre         A veces
# 3              Nunca         Siempre         Siempre         A veces
# 4              Nunca  Constantemente         Siempre         A veces
# ...              ...             ...             ...             ...
# 5265         A veces         A veces  Constantemente         A veces
# 5266         Siempre         Siempre         Siempre  Constantemente
# 5267  Constantemente  Constantemente  Constantemente  Constantemente
# 5268           Nunca  Constantemente  Constantemente  Constantemente
# 5269           Nunca  Constantemente  Constantemente  Constantemente
#
#                  p15      p16             p17             p18             p19  \
# 0            Siempre  A veces         Siempre  Constantemente  Constantemente
# 1            Siempre  A veces         A veces           Nunca         A veces
# 2            Siempre  A veces         Siempre           Nunca         Siempre
# 3            A veces    Nunca         Siempre         A veces  Constantemente
# 4            Siempre  A veces         Siempre           Nunca         Siempre
# ...              ...      ...             ...             ...             ...
# 5265  Constantemente    Nunca  Constantemente           Nunca         A veces
# 5266         Siempre  A veces         Siempre           Nunca  Constantemente
# 5267         Siempre  A veces  Constantemente           Nunca  Constantemente
# 5268         Siempre  A veces         Siempre         A veces         Siempre
# 5269         Siempre  A veces  Constantemente           Nunca  Constantemente
#
#           p20
# 0       Nunca
# 1       Nunca
# 2       Nunca
# 3       Nunca
# 4       Nunca
# ...       ...
# 5265    Nunca
# 5266    Nunca
# 5267  A veces
# 5268  A veces
# 5269    Nunca
#
# [5270 rows x 33 columns]
# --------------------------------------------------------
# Base de preguntas:
#                                        Antiguo_Nombre Nuevo_Nombre  \
# 0   Reconoce una amplia gama de técnicas para gene...           p1
# 1   Le es difícil construir, mejorar, analizar o e...           p2
# 2   Es abierto y sensible a perspectivas nuevas y ...           p3
# 3   Cuando falla, intenta olvidar lo sucedido y si...           p4
# 4   Comprende los sistemas y estrategias para abor...           p5
# 5   Utiliza varios tipos de razonamiento  (inducti...           p6
# 6   Saca conclusiones que no están basadas en la i...           p7
# 7   Cuando intenta identificar formas de resolver ...           p8
# 8   Aborda situaciones haciendo razonamientos desd...           p9
# 9   Analiza y evalúa los diferentes componentes de...          p10
# 10  Confía plenamente en la información que consul...          p11
# 11  Hace preguntas significativas que evidencian v...          p12
# 12  Demuestra capacidad para trabajar respetuosame...          p13
# 13  Cuando trabaja en equipo usted se mantiene fir...          p14
# 14  Respeta las diferencias culturales y trabaja e...          p15
# 15  Las personas externas difícilmente aportan a l...          p16
# 16  Es consciente de varios tipos de interacción v...          p17
# 17  En contextos complejos, sus comunicaciones no ...          p18
# 18  Cuando entrega un mensaje, hablado o escrito, ...          p19
# 19  Le cuesta trabajo dialogar de manera construct...          p20
#
#                  Competencia Invertida
# 0   CREATIVIDAD E INNOVACION        No
# 1   CREATIVIDAD E INNOVACION        Si
# 2   CREATIVIDAD E INNOVACION        No
# 3   CREATIVIDAD E INNOVACION        Si
# 4    RESOLUCION DE PROBLEMAS        No
# 5    RESOLUCION DE PROBLEMAS        No
# 6    RESOLUCION DE PROBLEMAS        Si
# 7    RESOLUCION DE PROBLEMAS        Si
# 8        PENSAMIENTO CRITICO        No
# 9        PENSAMIENTO CRITICO        No
# 10       PENSAMIENTO CRITICO        Si
# 11       PENSAMIENTO CRITICO        No
# 12      TRABAJO COLABORATIVO        No
# 13      TRABAJO COLABORATIVO        Si
# 14      TRABAJO COLABORATIVO        No
# 15      TRABAJO COLABORATIVO        Si
# 16              COMUNICACIÓN        No
# 17              COMUNICACIÓN        Si
# 18              COMUNICACIÓN        No
# 19              COMUNICACIÓN        Si
# --------------------------------------------------------
# Lista de variables en la base de datos:
# Index(['ID', 'Year', 'Mes', 'solucion', 'regional', 'departamento',
#        'ubicacioninstitucion', 'cargo', 'edades', 'formacion', 'sexoinscrito',
#        'Marca temporal', 'formulario', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6',
#        'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16',
#        'p17', 'p18', 'p19', 'p20'],
#       dtype='object')
# --------------------------------------------------------
# La base de datos tiene 5270 observaciones y 33 variables.

# %% [markdown]
# ##  Análisis preliminar

# %%
## Revisando valores faltantes
def revision_tipos_nans(df):
    '''
    Función que imprime el nombre de la columna, tipo de dato y cantidad de vaciós y porcentaje
    '''
    for col in df.columns:
        if df[col].hasnans:
            print(
                f"La variable \033[1m{col}\033[0;0m ({df[col].dtypes}): \
Contiene \033[1m{df[col].isnull().sum()}\033[0;0m ( \
\033[1m{round(df[col].isnull().sum()*100/len(df),2)}%\033[0;0m ) \
valores vacíos"
            )


revision_tipos_nans(data)
# Out:
# La variable regional (object): Contiene 85 ( 1.61% ) valores vacíos
# La variable departamento (object): Contiene 1 ( 0.02% ) valores vacíos
# La variable ubicacioninstitucion (object): Contiene 1 ( 0.02% ) valores vacíos
# La variable cargo (object): Contiene 16 ( 0.3% ) valores vacíos
# La variable edades (object): Contiene 15 ( 0.28% ) valores vacíos
# La variable formacion (object): Contiene 16 ( 0.3% ) valores vacíos
# La variable sexoinscrito (object): Contiene 15 ( 0.28% ) valores vacíos

# %% [markdown]
# Se procede a eliminar los missing en la variable regional, ya que para la fundación Future Education es un requisito saber con certeza la regional a la que pertenece un docente:

# %%
## Eliminar missing
print(
    f"La base de datos original tiene {data.shape[0]} \
observaciones y {data.shape[1]} variables."
)

data.dropna(inplace=True, subset = ["regional"])
print("--------------------------------------------------------")
print(
    f"\nLa base de datos después de eliminar los missing tiene {data.shape[0]} \
observaciones y {data.shape[1]} variables."
)
# Out:
# La base de datos original tiene 5270 observaciones y 33 variables.
# --------------------------------------------------------
#
# La base de datos después de eliminar los missing tiene 5185 observaciones y 33 variables.

# %% [markdown]
# Se procede a revisar los valores únicos de cada dato.

# %%
for col in data.columns:
    print(f'\033[1m{col}\033[0;0m:', len(data[col].unique()))
# Out:
# ID: 3809
# Year: 2
# Mes: 12
# solucion: 14
# regional: 5
# departamento: 32
# ubicacioninstitucion: 4
# cargo: 8
# edades: 9
# formacion: 9
# sexoinscrito: 5
# Marca temporal: 5185
# formulario: 2
# p1: 4
# p2: 4
# p3: 4
# p4: 4
# p5: 4
# p6: 4
# p7: 4
# p8: 4
# p9: 4
# p10: 4
# p11: 4
# p12: 4
# p13: 4
# p14: 4
# p15: 4
# p16: 4
# p17: 4
# p18: 4
# p19: 4
# p20: 4

# %% [markdown]
# Para aquellos con menos de 33, se procede a observar el valor en si (esto es, para observar valores relevantes quizá no conocidos, donde 33 es el tamaño del valor más grande más 1)

# %%
def revisar_valores_unicos(data, max_size=33):
    print("--------------------------------------------------------")
    print(f'Revisando valores unicos:\n\n')
    lista = list(data.columns)
    for i in lista:
        if len(data[i].unique()) < max_size:
            print(f'La columna \033[1m{i}\033[0;0m: tiene los siguientes valores\
    \n{data[i].unique()}\n')
        else:
            print(f'La columna \033[1m{i}\033[0;0m: tiene más de {max_size} dominios\n')
revisar_valores_unicos(data, max_size=33)
# Out:
# --------------------------------------------------------
# Revisando valores unicos:
#
#
# La columna ID: tiene más de 33 dominios
#
# La columna Year: tiene los siguientes valores
# [2022 2023]
#
# La columna Mes: tiene los siguientes valores
# [ 3  6  8  4 11  7  5 12  1 10  2  9]
#
# La columna solucion: tiene los siguientes valores
# ['LABORATORIO VIVO' 'ESTUDIA' 'Modelos Educativos Flexibles'
#  'Fortalecimiento CDIs' 'Fortalecimiento IE' 'LA VUELTA AL MUNDO'
#  'ESCUELAS LABORATORIO' 'PROYECTO ESPECIAL' 'RAS' 'Nube9'
#  'CENTROS DEMOSTRATIVOS' 'LABORATORIO ÁGIL' 'EDULABS' 'LA GRAN TRANSICIÓN']
#
# La columna regional: tiene los siguientes valores
# ['Centro' 'Caribe' 'Antioquia' 'Suroccidente' 'Nacional']
#
# La columna departamento: tiene los siguientes valores
# ['CUNDINAMARCA' 'VALLE DEL CAUCA' 'ATLÁNTICO' 'CALDAS' 'ANTIOQUIA' 'CESAR'
#  'ARAUCA' 'BOGOTÁ D.C.' 'META' 'GUAVIARE' 'QUINDIO' 'BOLÍVAR' 'CAUCA'
#  'CÓRDOBA' 'SANTANDER' 'AMAZONAS' 'MAGDALENA' 'CASANARE' 'CHOCÓ' 'NARIÑO'
#  'TOLIMA' 'NINGUNO' 'BOYACÁ' 'HUILA' 'LA GUAJIRA' 'RISARALDA'
#  'NORTE DE SANTANDER' 'SUCRE' 'PUTUMAYO' 'CAQUETÁ' nan 'EXTRANJERO']
#
# La columna ubicacioninstitucion: tiene los siguientes valores
# ['rural' 'urbana' 'ninguna' nan]
#
# La columna cargo: tiene los siguientes valores
# ['Docente' 'Agente Educativo' 'Administrativo' 'Estudiante' 'Empleado' nan
#  'Ninguno' 'Voluntario']
#
# La columna edades: tiene los siguientes valores
# ['Entre 26 y 35 años' 'Mayor de 55 años' 'Entre 36 y 45 años'
#  'Entre 15 y 17 años' 'Entre 46 y 55 años' 'Entre 0 y 6 años' nan
#  'Entre 18 y 25 años' 'Entre 7 y 14 años']
#
# La columna formacion: tiene los siguientes valores
# ['Profesional' 'Posgrado' 'Ninguna' 'Tecnólogo' 'Estudiante Universitario'
#  'Normalista' 'Bachiller' 'Técnico' nan]
#
# La columna sexoinscrito: tiene los siguientes valores
# ['mujer' 'hombre' 'otro' nan 'Mujer']
#
# La columna Marca temporal: tiene más de 33 dominios
#
# La columna formulario: tiene los siguientes valores
# ['Entrada' 'Salida']
#
# La columna p1: tiene los siguientes valores
# ['A veces' 'Siempre' 'Constantemente' 'Nunca']
#
# La columna p2: tiene los siguientes valores
# ['A veces' 'Nunca' 'Siempre' 'Constantemente']
#
# La columna p3: tiene los siguientes valores
# ['Siempre' 'A veces' 'Constantemente' 'Nunca']
#
# La columna p4: tiene los siguientes valores
# ['Nunca' 'A veces' 'Constantemente' 'Siempre']
#
# La columna p5: tiene los siguientes valores
# ['A veces' 'Constantemente' 'Siempre' 'Nunca']
#
# La columna p6: tiene los siguientes valores
# ['A veces' 'Constantemente' 'Siempre' 'Nunca']
#
# La columna p7: tiene los siguientes valores
# ['A veces' 'Nunca' 'Constantemente' 'Siempre']
#
# La columna p8: tiene los siguientes valores
# ['A veces' 'Nunca' 'Constantemente' 'Siempre']
#
# La columna p9: tiene los siguientes valores
# ['A veces' 'Constantemente' 'Siempre' 'Nunca']
#
# La columna p10: tiene los siguientes valores
# ['A veces' 'Siempre' 'Constantemente' 'Nunca']
#
# La columna p11: tiene los siguientes valores
# ['Constantemente' 'Nunca' 'A veces' 'Siempre']
#
# La columna p12: tiene los siguientes valores
# ['Constantemente' 'Siempre' 'A veces' 'Nunca']
#
# La columna p13: tiene los siguientes valores
# ['Constantemente' 'Siempre' 'A veces' 'Nunca']
#
# La columna p14: tiene los siguientes valores
# ['Constantemente' 'A veces' 'Siempre' 'Nunca']
#
# La columna p15: tiene los siguientes valores
# ['Siempre' 'A veces' 'Constantemente' 'Nunca']
#
# La columna p16: tiene los siguientes valores
# ['A veces' 'Nunca' 'Constantemente' 'Siempre']
#
# La columna p17: tiene los siguientes valores
# ['Siempre' 'A veces' 'Constantemente' 'Nunca']
#
# La columna p18: tiene los siguientes valores
# ['Constantemente' 'Nunca' 'A veces' 'Siempre']
#
# La columna p19: tiene los siguientes valores
# ['Constantemente' 'A veces' 'Siempre' 'Nunca']
#
# La columna p20: tiene los siguientes valores
# ['Nunca' 'A veces' 'Constantemente' 'Siempre']

# %% [markdown]
# Se encuentran errores en los dominios:
# - departamento: el dominio NINGUNO no es un valor valido y se debe imputar o eliminar.
# - ubicacioninstitucion: la ubicación ninguna no es valida, debe ser urbana o rural
# - edades: todos son docentes, maestros o agentes educativos, por lo que todos son mayores de edad; las edades 0 a 6, 7 a 14 y 15 a 17, no son validas, se debe imputar o eliminar.
# - sexoinscrito: la opción Mujer no es valida, se debe reemplazar por mujer.

# %%
## Revisando valores unicos
print("--------------------------------------------------------")
print(f'Revisando cantidad de datos con errores en sus dominios:')
print(f'departamento: {len(data[data.departamento.isin(["NINGUNO"])])}')
print(f"ubicacioninstitucion: {len(data[data.ubicacioninstitucion.isin(['ninguna'])])}")
print(f"edades: {len(data[data.edades.isin(['Entre 0 y 6 años', 'Entre 7 y 14 años', 'Entre 15 y 17 años'])])}")
print(f"sexoinscrito: {len(data[data.sexoinscrito.isin(['Mujer'])])}")
# Out:
# --------------------------------------------------------
# Revisando cantidad de datos con errores en sus dominios:
# departamento: 5
# ubicacioninstitucion: 162
# edades: 460
# sexoinscrito: 2

# %%
data['edades'].value_counts().rename_axis('Rol').reset_index(name='Frecuencia')
# Out:
#                   Rol  Frecuencia
# 0  Entre 26 y 35 años        1529
# 1  Entre 36 y 45 años        1505
# 2  Entre 46 y 55 años         950
# 3    Mayor de 55 años         528
# 4    Entre 0 y 6 años         444
# 5  Entre 18 y 25 años         198
# 6   Entre 7 y 14 años           8
# 7  Entre 15 y 17 años           8

# %% [markdown]
# ### Imputación univariada
#
# La imputación univariada consiste en utilizar únicamente la información que posee la variable que se está imputando para poder establecer valores numéricos en las observaciones que corresponde. Además, puede escogerse el método para calcular el valor con el que se reemplazarán los datos faltantes.

# %%
# Reemplazar los valores incorrectos con NaN
data["departamento"] = data["departamento"].replace("NINGUNO", np.nan)
data["ubicacioninstitucion"] = data["ubicacioninstitucion"].replace("ninguna", np.nan)
data["edades"] = data["edades"].replace(
    ["Entre 0 y 6 años", "Entre 7 y 14 años", "Entre 15 y 17 años"], np.nan
)
data["sexoinscrito"] = data["sexoinscrito"].replace("Mujer", np.nan)

# %%
data.isna().sum()
# Out:
# ID                        0
# Year                      0
# Mes                       0
# solucion                  0
# regional                  0
# departamento              6
# ubicacioninstitucion    163
# cargo                    16
# edades                  475
# formacion                16
# sexoinscrito             17
# Marca temporal            0
# formulario                0
# p1                        0
# p2                        0
# p3                        0
# p4                        0
# p5                        0
# p6                        0
# p7                        0
# p8                        0
# p9                        0
# p10                       0
# p11                       0
# p12                       0
# p13                       0
# p14                       0
# p15                       0
# p16                       0
# p17                       0
# p18                       0
# p19                       0
# p20                       0
# dtype: int64

# %%
## Imputar con la moda
estrategia="most_frequent"

imp = SimpleImputer(missing_values=np.nan, strategy=estrategia)
imp.fit(data)
# Imputar los valores faltantes en el DataFrame
data_imputado = pd.DataFrame(imp.transform(data), columns=data.columns)
data_imputado.head()
# Out:
#   ID  Year Mes                      solucion regional     departamento  \
# 0  1  2022   3              LABORATORIO VIVO   Centro     CUNDINAMARCA
# 1  1  2022   6              LABORATORIO VIVO   Centro     CUNDINAMARCA
# 2  2  2022   8                       ESTUDIA   Centro  VALLE DEL CAUCA
# 3  3  2022   3                       ESTUDIA   Centro     CUNDINAMARCA
# 4  4  2022   4  Modelos Educativos Flexibles   Caribe        ATLÁNTICO
#
#   ubicacioninstitucion    cargo              edades    formacion  ...  \
# 0                rural  Docente  Entre 26 y 35 años  Profesional  ...
# 1                rural  Docente  Entre 26 y 35 años  Profesional  ...
# 2               urbana  Docente    Mayor de 55 años     Posgrado  ...
# 3               urbana  Docente  Entre 36 y 45 años     Posgrado  ...
# 4               urbana  Docente  Entre 36 y 45 años     Posgrado  ...
#
#               p11             p12             p13             p14      p15  \
# 0  Constantemente  Constantemente  Constantemente  Constantemente  Siempre
# 1  Constantemente         Siempre  Constantemente  Constantemente  Siempre
# 2  Constantemente         Siempre         Siempre         A veces  Siempre
# 3           Nunca         Siempre         Siempre         A veces  A veces
# 4           Nunca  Constantemente         Siempre         A veces  Siempre
#
#        p16      p17             p18             p19    p20
# 0  A veces  Siempre  Constantemente  Constantemente  Nunca
# 1  A veces  A veces           Nunca         A veces  Nunca
# 2  A veces  Siempre           Nunca         Siempre  Nunca
# 3    Nunca  Siempre         A veces  Constantemente  Nunca
# 4  A veces  Siempre           Nunca         Siempre  Nunca
#
# [5 rows x 33 columns]

# %%
revisar_valores_unicos(data, max_size=33)
# Out:
# --------------------------------------------------------
# Revisando valores unicos:
#
#
# La columna ID: tiene más de 33 dominios
#
# La columna Year: tiene los siguientes valores
# [2022 2023]
#
# La columna Mes: tiene los siguientes valores
# [ 3  6  8  4 11  7  5 12  1 10  2  9]
#
# La columna solucion: tiene los siguientes valores
# ['LABORATORIO VIVO' 'ESTUDIA' 'Modelos Educativos Flexibles'
#  'Fortalecimiento CDIs' 'Fortalecimiento IE' 'LA VUELTA AL MUNDO'
#  'ESCUELAS LABORATORIO' 'PROYECTO ESPECIAL' 'RAS' 'Nube9'
#  'CENTROS DEMOSTRATIVOS' 'LABORATORIO ÁGIL' 'EDULABS' 'LA GRAN TRANSICIÓN']
#
# La columna regional: tiene los siguientes valores
# ['Centro' 'Caribe' 'Antioquia' 'Suroccidente' 'Nacional']
#
# La columna departamento: tiene los siguientes valores
# ['CUNDINAMARCA' 'VALLE DEL CAUCA' 'ATLÁNTICO' 'CALDAS' 'ANTIOQUIA' 'CESAR'
#  'ARAUCA' 'BOGOTÁ D.C.' 'META' 'GUAVIARE' 'QUINDIO' 'BOLÍVAR' 'CAUCA'
#  'CÓRDOBA' 'SANTANDER' 'AMAZONAS' 'MAGDALENA' 'CASANARE' 'CHOCÓ' 'NARIÑO'
#  'TOLIMA' nan 'BOYACÁ' 'HUILA' 'LA GUAJIRA' 'RISARALDA'
#  'NORTE DE SANTANDER' 'SUCRE' 'PUTUMAYO' 'CAQUETÁ' 'EXTRANJERO']
#
# La columna ubicacioninstitucion: tiene los siguientes valores
# ['rural' 'urbana' nan]
#
# La columna cargo: tiene los siguientes valores
# ['Docente' 'Agente Educativo' 'Administrativo' 'Estudiante' 'Empleado' nan
#  'Ninguno' 'Voluntario']
#
# La columna edades: tiene los siguientes valores
# ['Entre 26 y 35 años' 'Mayor de 55 años' 'Entre 36 y 45 años' nan
#  'Entre 46 y 55 años' 'Entre 18 y 25 años']
#
# La columna formacion: tiene los siguientes valores
# ['Profesional' 'Posgrado' 'Ninguna' 'Tecnólogo' 'Estudiante Universitario'
#  'Normalista' 'Bachiller' 'Técnico' nan]
#
# La columna sexoinscrito: tiene los siguientes valores
# ['mujer' 'hombre' 'otro' nan]
#
# La columna Marca temporal: tiene más de 33 dominios
#
# La columna formulario: tiene los siguientes valores
# ['Entrada' 'Salida']
#
# La columna p1: tiene los siguientes valores
# ['A veces' 'Siempre' 'Constantemente' 'Nunca']
#
# La columna p2: tiene los siguientes valores
# ['A veces' 'Nunca' 'Siempre' 'Constantemente']
#
# La columna p3: tiene los siguientes valores
# ['Siempre' 'A veces' 'Constantemente' 'Nunca']
#
# La columna p4: tiene los siguientes valores
# ['Nunca' 'A veces' 'Constantemente' 'Siempre']
#
# La columna p5: tiene los siguientes valores
# ['A veces' 'Constantemente' 'Siempre' 'Nunca']
#
# La columna p6: tiene los siguientes valores
# ['A veces' 'Constantemente' 'Siempre' 'Nunca']
#
# La columna p7: tiene los siguientes valores
# ['A veces' 'Nunca' 'Constantemente' 'Siempre']
#
# La columna p8: tiene los siguientes valores
# ['A veces' 'Nunca' 'Constantemente' 'Siempre']
#
# La columna p9: tiene los siguientes valores
# ['A veces' 'Constantemente' 'Siempre' 'Nunca']
#
# La columna p10: tiene los siguientes valores
# ['A veces' 'Siempre' 'Constantemente' 'Nunca']
#
# La columna p11: tiene los siguientes valores
# ['Constantemente' 'Nunca' 'A veces' 'Siempre']
#
# La columna p12: tiene los siguientes valores
# ['Constantemente' 'Siempre' 'A veces' 'Nunca']
#
# La columna p13: tiene los siguientes valores
# ['Constantemente' 'Siempre' 'A veces' 'Nunca']
#
# La columna p14: tiene los siguientes valores
# ['Constantemente' 'A veces' 'Siempre' 'Nunca']
#
# La columna p15: tiene los siguientes valores
# ['Siempre' 'A veces' 'Constantemente' 'Nunca']
#
# La columna p16: tiene los siguientes valores
# ['A veces' 'Nunca' 'Constantemente' 'Siempre']
#
# La columna p17: tiene los siguientes valores
# ['Siempre' 'A veces' 'Constantemente' 'Nunca']
#
# La columna p18: tiene los siguientes valores
# ['Constantemente' 'Nunca' 'A veces' 'Siempre']
#
# La columna p19: tiene los siguientes valores
# ['Constantemente' 'A veces' 'Siempre' 'Nunca']
#
# La columna p20: tiene los siguientes valores
# ['Nunca' 'A veces' 'Constantemente' 'Siempre']

# %% [markdown]
# Se realizó la imputación de los datos por los valores mas frecuentes, ya que por conocimiento del negocio, la mayoría de faltantes ocurren por "obviar" la característica más presente (ejemplo, muchos no diligencian que están en Antioquia por su institución solo tener sede en Antioquia)

# %% [markdown]
# ## Visualización

# %%
# Variables categóricas
categorical_variables = [
    "ubicacioninstitucion",
    "cargo",
    "edades",
    "formacion",
    "sexoinscrito",
    "formulario",
    "regional",
    "departamento",
]

# Configura un diseño de cuadrícula para mostrar múltiples gráficos
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 30)) #3 filas 3 columnas
plt.subplots_adjust(wspace=0.2, hspace=0.2)  # Espaciado entre los gráficos

# Itera a través de las variables categóricas y crea gráficos de barras
for i, variable in enumerate(categorical_variables):
    row, col = i // 2, i % 2  # Calcula la fila y columna actual
    ax = axes[row, col]  # Obtén el eje actual

    # Cuenta las ocurrencias de cada categoría y crea un gráfico de barras
    counts = data_imputado[variable].value_counts()
    ax.bar(counts.index, counts.values, color="#19b2c8")
    ax.set_title(f"Distribución de {variable}")
    ax.set_xlabel(variable)
    ax.set_ylabel("Frecuencia")
    ax.tick_params(
        axis="x", rotation=90
    )  # Rotar etiquetas del eje x para mejorar la legibilidad

    # Agrega etiquetas de datos en las barras
    for j, v in enumerate(counts.values):
        ax.text(j, v, str(v), ha="center", va="bottom")


# Ajusta automáticamente los márgenes
plt.tight_layout()
plt.show()

# %%
# Variables p1 a p20
variables_p = [
    "p1",
    "p2",
    "p3",
    "p4",
    "p5",
    "p6",
    "p7",
    "p8",
    "p9",
    "p10",
    "p11",
    "p12",
    "p13",
    "p14",
    "p15",
    "p16",
    "p17",
    "p18",
    "p19",
    "p20",
]

# Definir el orden personalizado de las respuestas
orden = ["Nunca", "A veces", "Constantemente", "Siempre"]


# Configura un diseño de cuadrícula para mostrar múltiples gráficos
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(15, 20))  # 3 filas 3 columnas
plt.subplots_adjust(wspace=0.2, hspace=0.2)  # Espaciado entre los gráficos

# Itera a través de las variables categóricas y crea gráficos de barras
for i, variable in enumerate(variables_p):
    row, col = i // 4, i % 4  # Calcula la fila y columna actual
    ax = axes[row, col]  # Obtén el eje actual

    # Cuenta las ocurrencias de cada categoría y crea un gráfico de barras
    counts = data_imputado[variable].value_counts()
    ax.bar(counts.index, counts.values, color="#19b2c8")
    ax.set_title(f"Distribución de {variable}")
    ax.set_xlabel(variable)
    ax.set_ylabel("Frecuencia")
    ax.tick_params(
        axis="x", rotation=90
    )  # Rotar etiquetas del eje x para mejorar la legibilidad

    # Agrega etiquetas de datos en las barras
    for j, v in enumerate(counts.values):
        ax.text(j, v, str(v), ha="center", va="bottom")


# Ajusta automáticamente los márgenes
plt.tight_layout()
plt.show()

# %%
# Mapear las respuestas a los valores numéricos
mapeo_respuestas = {
    "Nunca": 1,
    "A veces": 2,
    "Constantemente": 3,
    "Siempre": 4
}

# Variables p1 a p20
variables_p = ['p1', 'p2', 'p3', 'p4', #Creatividad e innovación
               'p5', 'p6', 'p7', 'p8', # Resolucion de problemas
               'p9', 'p10', 'p11', 'p12', # Pensamiento critico
               'p13', 'p14', 'p15', 'p16', # Trabajo colaborativo
               'p17', 'p18', 'p19', 'p20'] # Comunicación

# Aplicar el mapeo a las columnas correspondientes
for variable in variables_p:
    data_imputado[variable] = data_imputado[variable].replace(mapeo_respuestas)

# %%
data_imputado.head()
# Out:
#   ID  Year Mes                      solucion regional     departamento  \
# 0  1  2022   3              LABORATORIO VIVO   Centro     CUNDINAMARCA
# 1  1  2022   6              LABORATORIO VIVO   Centro     CUNDINAMARCA
# 2  2  2022   8                       ESTUDIA   Centro  VALLE DEL CAUCA
# 3  3  2022   3                       ESTUDIA   Centro     CUNDINAMARCA
# 4  4  2022   4  Modelos Educativos Flexibles   Caribe        ATLÁNTICO
#
#   ubicacioninstitucion    cargo              edades    formacion  ... p11 p12  \
# 0                rural  Docente  Entre 26 y 35 años  Profesional  ...   3   3
# 1                rural  Docente  Entre 26 y 35 años  Profesional  ...   3   4
# 2               urbana  Docente    Mayor de 55 años     Posgrado  ...   3   4
# 3               urbana  Docente  Entre 36 y 45 años     Posgrado  ...   1   4
# 4               urbana  Docente  Entre 36 y 45 años     Posgrado  ...   1   3
#
#   p13  p14  p15  p16  p17  p18  p19  p20
# 0   3    3    4    2    4    3    3    1
# 1   3    3    4    2    2    1    2    1
# 2   4    2    4    2    4    1    4    1
# 3   4    2    2    1    4    2    3    1
# 4   4    2    4    2    4    1    4    1
#
# [5 rows x 33 columns]
